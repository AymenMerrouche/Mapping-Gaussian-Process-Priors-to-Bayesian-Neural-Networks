# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import numpy as np

from blitz.modules import BayesianLinear
from blitz.utils import variational_estimator

import math

import matplotlib.pyplot as plt

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from modules.BNN.BNN_reg import *
from modules.data.data_utils import *
from modules.data.uniform_distribution import *

# %%
trainloader, testloader = get_data_loaders(UniformDistributionDataset())
regressor = BayesianRegressor(1, 1)

# %%
plt.figure(figsize=(30, 10))
ax = plt.subplot(1, 1, 1)
regressor.sample(ax=ax)

# %%
# Let's check if we are really using a diagonal gaussian prior (initial posterior on weights p(w | phi))
def softplus(x):
    return np.log(1. + np.exp(x))
# step 1: check first layer
print("first linear layer :")
print("var : ",softplus(regressor.blinear1.posterior_rho_init))
print("mean : ",regressor.blinear1.posterior_mu_init)
# step 2: check second layer
print("second linear layer :")
print("var : ",softplus(regressor.blinear2.posterior_rho_init))
print("mean : ",regressor.blinear2.posterior_mu_init)
# Out:
# first linear layer :
# var :  0.9999999618701924
# mean :  0
# second linear layer :
# var :  0.9999999618701924
# mean :  0
